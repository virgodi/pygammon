# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
acc = [0.66, .68, 0.90, 0.93, 0.79]

# %%
dictionary = plt.figure(figsize=(15,8))

D = {u'MLR (small)': 0.66, u'GA (small)': 0.68, u'MLR (large)': 0.90, u'GA (large)': 0.93, u'Q-L': 0.79}

plt.bar(range(len(D)), D.values(), align='center')
plt.xticks(range(len(D)), D.keys(),  rotation=45, fontsize=20)
plt.ylabel('Percentage', fontsize=20)
plt.show()
